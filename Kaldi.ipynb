# %% [markdown]
# <a href="https://colab.research.google.com/github/lazybutbusy/KaldiTesting/blob/master/Kaldi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.Setup Kaldi in Colab**

# %%
#Install automake
# !apt-get install -qq g++ automake autoconf libtool subversion
#Install sox
# !apt-get install libsox-fmt-all libsox-dev sox
#Clone kaldi
# !git clone https://github.com/kaldi-asr/kaldi.git

#Go to kaldi/tools
# %cd ../content/kaldi/tools
#Make Kaldi with 8 threads
# !make -j8

#Install OPENBLAS
# !extras/install_openblas.sh
#Go to kaldi/src
# %cd ../src
#Run configure folder
# !./configure --shared --mathlib=OPENBLAS
#Make Configure with 8 threads
# !make depend -j 8
# Out:
# cc -O2 -DMAX_STACK_ALLOC=2048 -DUSE_LOCKING -Wall -m64 -DF_INTERFACE_GFORT -fPIC -DNO_WARMUP -DMAX_CPU_NUMBER=2 -DMAX_PARALLEL_NUMBER=1 -DVERSION="0.3.7" -mavx2 -DASMNAME= -DASMFNAME=_ -DNAME=_ -DCNAME= -DCHAR_NAME="_" -DCHAR_CNAME="" -DNO_AFFINITY -I. -DHAVE_LAPACK_CONFIG_H -I../include -c -o lapacke_sgbtrs_work.o lapacke_sgbtrs_work.c
# cc -O2 -DMAX_STACK_ALLOC=2048 -DUSE_LOCKING -Wall -m64 -DF_INTERFACE_GFORT -fPIC -DNO_WARMUP -DMAX_CPU_NUMBER=2 -DMAX_PARALLEL_NUMBER=1 -DVERSION="0.3.7" -mavx2 -DASMNAME= -DASMFNAME=_ -DNAME=_ -DCNAME= -DCHAR_NAME="_" -DCHAR_CNAME="" -DNO_AFFINITY -I. -DHAVE_LAPACK_CONFIG_H -I../include -c -o lapacke_sgebak.o lapacke_sgebak.c
# ...

# %%
# %cd ../content/kaldi/src
#Run configure folder
# !./configure --shared --mathlib=OPENBLAS
#Make Configure with 8 threads
# !make depend -j 8
# Out:
# /content/kaldi/src
# Configuring KALDI to use OPENBLAS.
# Checking compiler g++ ...
# Checking OpenFst library in /content/kaldi/tools/openfst-1.6.7 ...
# Checking cub library in /content/kaldi/tools/cub-1.8.0 ...
# Performing OS specific configuration ...
# On Linux: Checking for linear algebra header files ...
# Your math library seems to be OpenBLAS from /content/kaldi/tools/OpenBLAS/install.  Configuring appropriately.
# Configuring dynamically loaded OpenBlas since --static-math=no (the default)
# Successfully configured for Linux with OpenBLAS from /content/kaldi/tools/OpenBLAS/install
# Using CUDA toolkit /usr/local/cuda (nvcc compiler and runtime libraries)
# INFO: Configuring Kaldi not to link with Speex. Don't worry, it's only needed if
#       you intend to use 'compress-uncompress-speex', which is very unlikely.
# Kaldi has been successfully configured. To compile:
#
#   make -j clean depend; make -j <NCPU>
#
# ...

# %% [markdown]
# # **2.Testing**

# %%
cd ../egs/rm/s5
# Out:
# /content/kaldi/egs/rm/s5

# %%
# !./run.sh
# Out:
# Error: rm_data_prep.sh requires a directory argument (an absolute pathname) that contains rm1_audio1 and rm1_audio2

# %%
# !cd

# %%
# !git clone https://github.com/foundintranslation/Kaldi
# Out:
# Cloning into 'Kaldi'...
# remote: Enumerating objects: 6100, done.
# remote: Total 6100 (delta 0), reused 0 (delta 0), pack-reused 6100
# Receiving objects: 100% (6100/6100), 23.08 MiB | 23.71 MiB/s, done.
# Resolving deltas: 100% (2909/2909), done.

# %%
cd Kaldi/egs/rm/s4
# Out:
# /content/kaldi/egs/rm/s5/Kaldi/egs/rm/s4

# %%
ls
# Out:
# conf/  getdata.sh*  local/  path.sh*  README.txt  run.sh*  scripts/  steps/

# %%
# !./getdata.sh
# Out:
# --2020-08-17 11:12:26--  http://www.speech.cs.cmu.edu/databases/rm1/rm1_cepstra.tar.gz
# Resolving www.speech.cs.cmu.edu (www.speech.cs.cmu.edu)... 128.2.204.214
# Connecting to www.speech.cs.cmu.edu (www.speech.cs.cmu.edu)|128.2.204.214|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37685843 (36M) [application/x-gzip]
# Saving to: '/content/kaldi/egs/rm/s5/Kaldi/egs/rm/s4/data/download/rm1_cepstra.tar.gz'
#
# rm1_cepstra.tar.gz  100%[===================>]  35.94M  2.61MB/s    in 14s
#
# 2020-08-17 11:12:40 (2.66 MB/s) - '/content/kaldi/egs/rm/s5/Kaldi/egs/rm/s4/data/download/rm1_cepstra.tar.gz' saved [37685843/37685843]
#
# --2020-08-17 11:12:40--  http://sourceforge.net/projects/kaldi/files/RM_G.fst
# Resolving sourceforge.net (sourceforge.net)... 216.105.38.13
# Connecting to sourceforge.net (sourceforge.net)|216.105.38.13|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# ...
